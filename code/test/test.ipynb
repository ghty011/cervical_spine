# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.arange(8)
a
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
b = a * 0.125
b
# Out:
# array([0.   , 0.125, 0.25 , 0.375, 0.5  , 0.625, 0.75 , 0.875])

# %%
label = 0.375
dist = np.power(label - b, 2)
dist
# Out:
# array([0.140625, 0.0625  , 0.015625, 0.      , 0.015625, 0.0625  ,
#        0.140625, 0.25    ])

# %%
plt.plot(np.exp(-50 * dist))
