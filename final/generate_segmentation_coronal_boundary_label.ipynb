# %%
import os
import glob
import nibabel as nib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from PIL import Image
from tqdm import tqdm

import csv

from torchvision.utils import draw_bounding_boxes

# %%
def read_patient_nii_mask(UID, seg_dir):
    nii_path = os.path.join(seg_dir, f"{UID}.nii")
    seg_mask = nib.load(nii_path).get_fdata()
    seg_mask = np.rot90(seg_mask, axes=(0, 1))
    seg_mask = seg_mask.transpose((2, 0, 1))
    seg_mask = np.flip(seg_mask, axis=0)
    seg_mask[seg_mask > 7] = 0
    return seg_mask

# %%
DATA_DIR = "/Volumes/SSD970/"

TRAIN_SEG_DIR = os.path.join(DATA_DIR, "segmentations")

# %%
patient_id = "1.2.826.0.1.3680043.1363"
masks = read_patient_nii_mask(patient_id, TRAIN_SEG_DIR)
masks.shape
# Out:
# (199, 512, 512)

# %%
xray_df = pd.read_csv(os.path.join(DATA_DIR, 'meta_xray.csv')).set_index('UID')
xray_df.head()
# Out:
#                            direction  z_spacing  pixel_spacing    aspect  \
# UID
# 1.2.826.0.1.3680043.10005          0      0.625       0.298828  2.091504
# 1.2.826.0.1.3680043.10005          1      0.625       0.298828  2.091504
# 1.2.826.0.1.3680043.10005          2      0.625       0.298828  2.091504
# 1.2.826.0.1.3680043.10014          0      0.800       0.234000  3.418803
# 1.2.826.0.1.3680043.10014          1      0.800       0.234000  3.418803
#
#                            width  height
# UID
# 1.2.826.0.1.3680043.10005    512     512
# 1.2.826.0.1.3680043.10005    512     541
# 1.2.826.0.1.3680043.10005    512     541
# 1.2.826.0.1.3680043.10014    512     512
# 1.2.826.0.1.3680043.10014    512     882

# %%
xray_seg = masks.max(axis=1)
aspect = xray_df.loc[patient_id].iloc[0].aspect
print(aspect)
_, axs = plt.subplots(1, 2, figsize=(12, 12))
# axs.set_aspect(10)
axs[0].axis('off')
axs[0].imshow(xray_seg, cmap='bone')
axs[0].set_aspect(aspect)

xray_img = Image.open(os.path.join(DATA_DIR, 'xray_images', patient_id, 'coronal.jpeg'))
axs[1].imshow(xray_img, cmap='bone')
plt.show()
# Out:
# 1.7123745819397993

# %%
xray_seg.shape
# Out:
# (199, 512)

# %%
header = [
    'UID', 'xmin','ymin','xmax','ymax','aspect'
]

f = open('segmentation_coronal_bbox.csv','w',newline='')
writer = csv.writer(f)
writer.writerow(header)
# Out:
# 32

# %%
def find_segmentation_boundary(xray_seg, throw=100, tol=0.01):
    h, w = xray_seg.shape
    rows, columns = xray_seg.nonzero()
    rows.sort()
    columns.sort()

    ymin, ymax = rows[throw] , rows[-throw]
    xmin, xmax = columns[throw], columns[-throw]

    width_tol = (xmax - xmin) * tol
    height_tol = (ymax - ymin) * tol

    xmin -= width_tol
    xmax += width_tol
    ymin -= height_tol
    ymax += height_tol

    xmin = max(0, xmin)
    xmax = min(w, xmax)
    ymin = max(0, ymin)
    ymax = min(h, ymax)

    return xmin, ymin, xmax, ymax

UID = '1.2.826.0.1.3680043.28665'
masks = read_patient_nii_mask(UID, TRAIN_SEG_DIR)
xray_seg = masks.max(axis=1)
aspect = xray_df.loc[UID].iloc[0].aspect
xmin, ymin, xmax, ymax = find_segmentation_boundary(xray_seg, throw=200, tol=0.1)
print(xmin, ymin * aspect, xmax, ymax * aspect)
plt.imshow(xray_seg, cmap='bone')
# plt.axis('off')
plt.axvline(xmin)
# plt.axvline(330)
plt.axvline(xmax)
plt.axhline(ymin)
# plt.axhline(100)
plt.axhline(ymax)
# Out:
# 124.2 123.4488888888889 373.8 553.528888888889

# %%
nii_paths = glob.glob(os.path.join(DATA_DIR, 'segmentations') + '/*.nii')

for nii_path in tqdm(nii_paths):
    UID = nii_path.split("/")[-1].replace(".nii","")
    masks = read_patient_nii_mask(UID, TRAIN_SEG_DIR)
    xray_seg = masks.max(axis=1)
    aspect = xray_df.loc[UID].iloc[0].aspect
    xmin, ymin, xmax, ymax = find_segmentation_boundary(xray_seg, throw=100, tol=0.1)

    writer.writerow([
        UID, xmin, ymin * aspect, xmax, ymax * aspect, aspect
    ])
# Out:
#   0%|          | 0/87 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3l/2d1zfhx90z18_kvtkwwz9xtw0000gn/T/ipykernel_39435/2453298631.py in <module>
#       8     xmin, ymin, xmax, ymax = find_segmentation_boundary(xray_seg, throw=100, tol=0.1)
#       9
# ---> 10     writer.writerow([
#      11         UID, xmin, ymin * aspect, xmax, ymax * aspect, aspect
#      12     ])
#
# ValueError: I/O operation on closed file.

# %%
f.close()

# %%
bbox_df = pd.read_csv('segmentation_coronal_bbox.csv').set_index('UID')
bbox_df.head()
# Out:
#                             xmin        ymin   xmax        ymax    aspect
# UID
# 1.2.826.0.1.3680043.10633  119.1  167.452055  405.9  619.835616  1.753425
# 1.2.826.0.1.3680043.10921  140.9   70.023582  406.1  494.682725  1.882354
# 1.2.826.0.1.3680043.11827  189.6   61.948092  350.4  397.288550  1.954198
# 1.2.826.0.1.3680043.11988   86.5    0.000000  416.5  728.139597  3.436242
# 1.2.826.0.1.3680043.12281   50.9  127.200000  460.1  840.800000  2.666667

# %%
def get_rectangle_edges_from_pascal_bbox(bbox):
    xmin_top_left, ymin_top_left, xmax_bottom_right, ymax_bottom_right = bbox

    bottom_left = (xmin_top_left, ymax_bottom_right)
    width = xmax_bottom_right - xmin_top_left
    height = ymin_top_left - ymax_bottom_right

    return bottom_left, width, height

def draw_pascal_voc_bboxes(
        plot_ax,
        bboxes,
        get_rectangle_corners_fn=get_rectangle_edges_from_pascal_bbox,
):
    for bbox in bboxes:
        bottom_left, width, height = get_rectangle_corners_fn(bbox)

        rect_1 = patches.Rectangle(
            bottom_left,
            width,
            height,
            linewidth=4,
            edgecolor="black",
            fill=False,
        )
        rect_2 = patches.Rectangle(
            bottom_left,
            width,
            height,
            linewidth=2,
            edgecolor="white",
            fill=False,
        )

        # Add the patch to the Axes
        plot_ax.add_patch(rect_1)
        plot_ax.add_patch(rect_2)

def show_image(
        image, bboxes=None, draw_bboxes_fn=draw_pascal_voc_bboxes, figsize=(10, 10)
):
    """

    :param image:
    :param bboxes: [[xmin, ymin, xmax, ymax]]
    :param draw_bboxes_fn:
    :param figsize:
    :return:
    """
    fig, ax = plt.subplots(1, figsize=figsize)
    ax.imshow(image)

    if bboxes is not None:
        draw_bboxes_fn(ax, bboxes)

    plt.show()

UID = '1.2.826.0.1.3680043.28665'
bbox = bbox_df.loc[UID,['xmin','ymin','xmax','ymax']].values
print(bbox)
image = Image.open(os.path.join(DATA_DIR, 'xray_images',UID,'coronal.jpeg'))
show_image(image, [bbox])
# Out:
# [117.8        119.75111111 384.2        560.07111111]

# %%
for i in range(len(bbox_df)):
    s = bbox_df.iloc[i]
    img = Image.open(os.path.join(DATA_DIR, 'xray_images',s.name, 'coronal.jpeg'))
    bbox = s[['xmin','ymin','xmax','ymax']].values
    bbox_img = draw_bounding_boxes(img, [bbox])
    plt.imshow(bbox_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3l/2d1zfhx90z18_kvtkwwz9xtw0000gn/T/ipykernel_42353/174658559.py in <module>
#       1 from torchvision.utils import draw_bounding_boxes
# ----> 2 for i in range(len(bbox_df)):
#       3     s = bbox_df.iloc[i]
#       4     img = Image.open(os.path.join(DATA_DIR, 'xray_images',s.name, 'coronal.jpeg'))
#       5     bbox = s[['xmin','ymin','xmax','ymax']].values
#
# NameError: name 'bbox_df' is not defined
